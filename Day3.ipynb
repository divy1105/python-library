# %%
import pandas as pd
df = pd.read_csv("titanic.csv")
d = pd.read_csv("AQI.csv")
d
# Out:
#      country              state           city  \
# 0      India     Andhra_Pradesh     Vijayawada
# 1      India     Andhra_Pradesh     Vijayawada
# 2      India     Andhra_Pradesh     Vijayawada
# 3      India     Andhra_Pradesh  Visakhapatnam
# 4      India  Arunachal_Pradesh     Naharlagun
# ...      ...                ...            ...
# 3298   India        West_Bengal        Kolkata
# 3299   India        West_Bengal        Kolkata
# 3300   India        West_Bengal        Kolkata
# 3301   India        West_Bengal        Kolkata
# 3302   India        West_Bengal       Siliguri
#
#                                      station          last_update   latitude  \
# 0            Rajiv Nagar, Vijayawada - APPCB  21-02-2026 10:00:00  16.554731
# 1            Rajiv Nagar, Vijayawada - APPCB  21-02-2026 10:00:00  16.554731
# 2            Rajiv Nagar, Vijayawada - APPCB  21-02-2026 10:00:00  16.554731
# 3     GVM Corporation, Visakhapatnam - APPCB  21-02-2026 10:00:00  17.720000
# ...

# %%
data = df['name'].str.split()

result=[]
for i in data:
    i[0],i[1]=i[1],i[0]
    result.append(' '.join(i))
df['name']=result
df['name']
# Out:
# 0                         Miss. Allen, Elisabeth Walton
# 1                        Master. Allison, Hudson Trevor
# 2                          Miss. Allison, Helen Loraine
# 3                  Mr. Allison, Hudson Joshua Creighton
# 4       Mrs. Allison, Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Miss. Zabour, Hileni
# 1305                              Miss. Zabour, Thamine
# 1306                          Mr. Zakarian, Mapriededer
# 1307                                Mr. Zakarian, Ortin
# 1308                                 Mr. Zimmerman, Leo
# Name: name, Length: 1309, dtype: object

# %%
d['station'].value_counts()
# Out:
# station
# Rajiv Nagar, Vijayawada - APPCB                          7
# ECIL Kapra, Hyderabad - TSPCB                            7
# Sector-3B Avas Vikas Colony, Agra - UPPCB                7
# Rohta, Agra - UPPCB                                      7
# Manoharpur, Agra - UPPCB                                 7
#                                                         ..
# Chhatrapati Shivaji Intl. Airport (T2), Mumbai - MPCB    4
# Collectorate, Gaya - BSPCB                               4
# Shasthri Nagar, Ratlam - IPCA Lab                        4
# Sector-2, Rourkela - OSPCB                               3
# Khunmoh, Srinagar - JKPCC                                3
# Name: count, Length: 497, dtype: int64

# %%
# Keep only the first part before the comma in 'station'
d['station'] = d['station'].str.split(',').str[0]

print(d['station'].head())
# Out:
# 0        Rajiv Nagar
# 1        Rajiv Nagar
# 2        Rajiv Nagar
# 3    GVM Corporation
# 4         Naharlagun
# Name: station, dtype: object

# %% [markdown]
# # 5.Removing Unwanted Columns from dataset

# %% [markdown]
# * Syntax ----> df.drop("cloumnName",axis=1,inplace=True)

# %%
dd=d['station'].str.split(',')
d['station']=dd[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 2
#       1 dd=d['station'].str.split(',')
# ----> 2 d['station']=dd[0]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4524, in DataFrame._set_item(self, key, value)
#    4514 def _set_item(self, key, value) -> None:
#    4515     """
#    4516     Add series to DataFrame in specified column.
#    4517
#    (...)
#    4522     ensure homogeneity.
#    4523     """
# -> 4524     value, refs = self._sanitize_column(value)
#    4526     if (
#    4527         key in self.columns
#    4528         and value.ndim == 1
# ...

# %%
d.drop("country", axis=1, inplace=True)
d
# Out:
#                   state           city           station          last_update  \
# 0        Andhra_Pradesh     Vijayawada       Rajiv Nagar  21-02-2026 10:00:00
# 1        Andhra_Pradesh     Vijayawada       Rajiv Nagar  21-02-2026 10:00:00
# 2        Andhra_Pradesh     Vijayawada       Rajiv Nagar  21-02-2026 10:00:00
# 3        Andhra_Pradesh  Visakhapatnam   GVM Corporation  21-02-2026 10:00:00
# 4     Arunachal_Pradesh     Naharlagun        Naharlagun  21-02-2026 10:00:00
# ...                 ...            ...               ...                  ...
# 3298        West_Bengal        Kolkata          Jadavpur  21-02-2026 10:00:00
# 3299        West_Bengal        Kolkata  Rabindra Sarobar  21-02-2026 10:00:00
# 3300        West_Bengal        Kolkata  Rabindra Sarobar  21-02-2026 10:00:00
# 3301        West_Bengal        Kolkata          Victoria  21-02-2026 10:00:00
# 3302        West_Bengal       Siliguri  Ward-32 Bapupara  21-02-2026 10:00:00
#
# ...

# %%
d['state'].unique()
d['state']=d['state'].str.replace('_',' ')
d
# Out:
#                   state           city           station          last_update  \
# 0        Andhra Pradesh     Vijayawada       Rajiv Nagar  21-02-2026 10:00:00
# 1        Andhra Pradesh     Vijayawada       Rajiv Nagar  21-02-2026 10:00:00
# 2        Andhra Pradesh     Vijayawada       Rajiv Nagar  21-02-2026 10:00:00
# 3        Andhra Pradesh  Visakhapatnam   GVM Corporation  21-02-2026 10:00:00
# 4     Arunachal Pradesh     Naharlagun        Naharlagun  21-02-2026 10:00:00
# ...                 ...            ...               ...                  ...
# 3298        West Bengal        Kolkata          Jadavpur  21-02-2026 10:00:00
# 3299        West Bengal        Kolkata  Rabindra Sarobar  21-02-2026 10:00:00
# 3300        West Bengal        Kolkata  Rabindra Sarobar  21-02-2026 10:00:00
# 3301        West Bengal        Kolkata          Victoria  21-02-2026 10:00:00
# 3302        West Bengal       Siliguri  Ward-32 Bapupara  21-02-2026 10:00:00
#
# ...

# %%
import numpy as np
d['pollutant_avg'].replace('NaN','0')
d['pollutant_avg']
# Out:
# 0         NaN
# 1         NaN
# 2        41.0
# 3         NaN
# 4       208.0
#         ...
# 3298      8.0
# 3299    123.0
# 3300     21.0
# 3301     25.0
# 3302     19.0
# Name: pollutant_avg, Length: 3303, dtype: float64

# %%
d['pollutant_avg'] = d['pollutant_avg'].replace('NaN', 0)
# d['pollutant_avg'] = d['pollutant_avg'].fillna(0)
# d['pollutant_min'] = d['pollutant_min'].fillna(0)
# d['pollutant_max'] = d['pollutant_max'].fillna(0)
d
# Out:
#                   state           city           station          last_update  \
# 0        Andhra Pradesh     Vijayawada       Rajiv Nagar  21-02-2026 10:00:00
# 1        Andhra Pradesh     Vijayawada       Rajiv Nagar  21-02-2026 10:00:00
# 2        Andhra Pradesh     Vijayawada       Rajiv Nagar  21-02-2026 10:00:00
# 3        Andhra Pradesh  Visakhapatnam   GVM Corporation  21-02-2026 10:00:00
# 4     Arunachal Pradesh     Naharlagun        Naharlagun  21-02-2026 10:00:00
# ...                 ...            ...               ...                  ...
# 3298        West Bengal        Kolkata          Jadavpur  21-02-2026 10:00:00
# 3299        West Bengal        Kolkata  Rabindra Sarobar  21-02-2026 10:00:00
# 3300        West Bengal        Kolkata  Rabindra Sarobar  21-02-2026 10:00:00
# 3301        West Bengal        Kolkata          Victoria  21-02-2026 10:00:00
# 3302        West Bengal       Siliguri  Ward-32 Bapupara  21-02-2026 10:00:00
#
# ...

# %%
import numpy as np

# Replace NaN (actual missing values) with 0
d['pollutant_avg'].fillna(0, inplace=True)
# Out:
# C:\Users\DIVY\AppData\Local\Temp\ipykernel_21272\3893966431.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d['pollutant_avg'].fillna(0, inplace=True)
