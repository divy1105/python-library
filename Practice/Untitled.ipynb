# %%
import pandas as pd
df=pd.read_csv("hr_data.csv")
df
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 1             1005               5                   262                   6
# 2             1486               7                   272                   4
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# ...            ...             ...                   ...                 ...
# 14994        87670               2                   151                   3
# 14995        87673               2                   160                   3
# 14996        87679               2                   143                   3
# 14997        87681               6                   280                   4
# 14998        87684               2                   158                   3
#
# ...

# %% [markdown]
# total no of emp based on department and salarywise

# %%
df.pivot_table(index=['department','salary'],values='employee_id',aggfunc='count')
# Out:
#                     employee_id
# department  salary
# IT          high             83
#             low             609
#             medium          535
# RandD       high             51
#             low             364
#             medium          372
# accounting  high             74
#             low             358
#             medium          335
# hr          high             45
#             low             335
#             medium          359
# management  high            225
#             low             180
#             medium          225
# marketing   high             80
#             low             402
#             medium          376
# product_mng high             68
#             low             451
#             medium          383
# sales       high            269
#             low            2099
#             medium         1772
# support     high            141
#             low            1146
#             medium          942
# ...

# %% [markdown]
# total no of projects handled by department and salarywise

# %%
df.pivot_table(index=['department','salary'],values='number_project',aggfunc='count')
# Out:
#                     number_project
# department  salary
# IT          high                83
#             low                609
#             medium             535
# RandD       high                51
#             low                364
#             medium             372
# accounting  high                74
#             low                358
#             medium             335
# hr          high                45
#             low                335
#             medium             359
# management  high               225
#             low                180
#             medium             225
# marketing   high                80
#             low                402
#             medium             376
# product_mng high                68
#             low                451
#             medium             383
# sales       high               269
#             low               2099
#             medium            1772
# support     high               141
# ...
